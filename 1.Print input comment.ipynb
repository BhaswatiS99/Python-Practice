# %%
#"Python Practice – Print, Input & Comments"

# %%
#Q1) Write a program that prints "Hello, World!" and then asks the user for their name and prints a personalized greeting.

# %%
print("Hello, World!")
user_name = input("Enter your name : ")
print("Hello" , user_name)
# Out:
# Hello, World!
# Enter your name :  Bhaswati
# Hello Bhaswati

# %%
#Q2) Ask the user for their name, age, and city. Print all three in a formatted "info card" style using multiple print statements with labels.

# %%
name = input("Enter your name : ")
age = input("Enter your age : ")
city = input("Enter your city : ")

print("--------------------------------")
print("    Bhaswati Saikia    ")
print("Data Analyst at AWA Pvt Ltd")
print("--------------------------------")
print(   "Name: " , name)
print(   "age: " , age)
print(   "city: " , city)
# Out:
# Enter your name :  Bhaswati
# Enter your age :  26
# Enter your city :  Delhi
# --------------------------------
#     Bhaswati Saikia
# Data Analyst at AWA Pvt Ltd
# --------------------------------
# Name:  Bhaswati
# age:  26
# city:  Delhi

# %%
#Q3) Ask the user for their favorite color, food, and movie. Print a sentence combining all three: "Your favorite color is blue, you love pizza, and your top movie is Inception."

# %%
colour = input("enter your favourite colour: ")
food = input("enter your favorite food: ")
movie = input("enter your favorite movie: ")

print(f"Your favorite colour is {colour} , you love {food} , your top movie is {movie}")
# Out:
# enter your favourite colour:  blue
# enter your favorite food:  pizza
# enter your favorite movie:  Inception
# your favorite colour is blue , you love pizza , your top movie is Inception

# %%
#Q4) Print a fake store receipt with item names and prices using print. Add comments in your code explaining what each section does.

# %%
#This section shows the store name and address
print("---------------------------------------------")
print("                ABC Store")
print("        MG road, Delhi, 110067")
print("---------------------------------------------")

#This section shows the receipt details

print("date: 01/01/2025              Time: 02:45:30PM")
print("Receipt No: SH12345")

#This section shows the item details, price, Qty, Amount
print("Item Name          Qty    Price    Amount")
print("--------------------------------------------")
print("Basmati Rice 5kg    1    Rs.320   Rs.320")
print("Tata Salt 1kg       2    Rs.22    Rs.44")
print("Amul Butter 500g    1    Rs.275   Rs.275")
print("Maggi Noodles       3    Rs.14    Rs.42")
print("Colgate Toothpaste  1    Rs.99    Rs.99")
print("--------------------------------------------")

# This section calculates and shows the final amounts
print("                   Subtotal:    Rs.780")
print("                   GST (5%):    Rs.39")
print("                   Discount:    -Rs.50")
print("------------------------")
print("                   TOTAL:       Rs.769")
print("============================================")

# This section shows how the customer paid
print("Payment Mode: UPI (GPay)")
print("Transaction ID: TXN2603131145")
print("--------------------------------------------")

# A thank you message at the bottom
print("   Thank you for shopping with us!")
print("        Visit us again :)")
print("============================================")
# Out:
# ---------------------------------------------
#                 ABC Store
#         MG road, Delhi, 110067
# ---------------------------------------------
# date: 01/01/2025              Time: 02:45:30PM
# Receipt No: SH12345
# Item Name          Qty    Price    Amount
# --------------------------------------------
# Basmati Rice 5kg    1    Rs.320   Rs.320
# Tata Salt 1kg       2    Rs.22    Rs.44
# Amul Butter 500g    1    Rs.275   Rs.275
# Maggi Noodles       3    Rs.14    Rs.42
# Colgate Toothpaste  1    Rs.99    Rs.99
# --------------------------------------------
#                    Subtotal:    Rs.780
#                    GST (5%):    Rs.39
#                    Discount:    -Rs.50
# ------------------------
#                    TOTAL:       Rs.769
# ...
# Payment Mode: UPI (GPay)
# Transaction ID: TXN2603131145
# --------------------------------------------
#    Thank you for shopping with us!
#         Visit us again :)
# ...

# %%
#Q5) Ask the user for their age in years. Multiply by 365 and print approximately how many days they have lived.

# %%
age = int(input("Enter your age : "))
days_lived = age*365
print(f"You've lived {days_lived} days so far in your life")
# Out:
# Enter your age :  26
# You've lived 9490 days so far in your life

# %%
#Q6) Ask the user for their name and one skill they have. Print an encouraging message like "Bhaswati, your Python skills are going to take you far!"

# %%
name = input("Enter your name: ")
skills = input("Enter your skills: ")
print(f"{name} your {skills} skills are going to take you far!")
# Out:
# Enter your name:  Bhaswati
# Enter your skills:  python
# Bhaswati your python skills are going to take you far!

# %%
#Q7) Ask the user for their name, job title, and email. Print a neatly formatted business card layout using print statements with spacing and separators like ---.

# %%
print("----------------------------------------")
print(" BHASWATI SAIKIA")
print(" Data Analyst | AWA Pvt Ltd")
print("----------------------------------------")
print(" Email  : bhaswatisaikia74@gmail.com")
print(" Phone  : +91-98765-43210")
print(" City   : Delhi")
print(" GitHub : github.com/BhaswatiS99")
print("----------------------------------------")
# Out:
# ----------------------------------------
#  BHASWATI SAIKIA
#  Data Analyst | AWA Pvt Ltd
# ----------------------------------------
#  Email  : bhaswatisaikia74@gmail.com
#  Phone  : +91-98765-43210
#  City   : Delhi
#  GitHub : github.com/BhaswatiS99
# ----------------------------------------

# %%
#Q8) Ask the user to enter three numbers one by one. Print their average with a label

# %%
num1 = int(input("first number: "))
num2 = int(input("second number: "))
num3 = int(input("third number: "))
Avg = (num1+num2+num3)/3
print("Average: " , Avg)
# Out:
# first number:  20
# second number:  30
# third number:  50
# Average:  33.333333333333336

# %%
#Q9) Ask the user for two values — call them A and B. Print them, then swap them and print again to show the swap happened.

# %%
a = int(input("first: "))
b = int(input("second: "))
print(a,b)
a,b = b,a
print(a,b)
# Out:
# first:  10
# second:  20
# 10 20
# 20 10

# %%
#Q10) Ask the user to type a sentence. Print how many characters (including spaces) are in it using

# %%
sentence = input("Write a sentence: ")
print(len(sentence))
# Out:
# Write a sentence:  I am Bhaswati, I'm from Assam currently staying in Delhi.
# 57
