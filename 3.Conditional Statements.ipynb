# %%
#CONDITIONAL STATEMENTS

# %%
#_________EASY____________

# %%
#Q1) Take a number as input. Print "Positive", "Negative", or "Zero" based on its value.

# %%
num = int(input("Enter any number: "))

if num > 0:
    print("Number is positive")
elif num < 0:
    print("nNumber is negative")
else:
    print("Zero")
# Out:
# Enter any number:  10
# Number is positive

# %%
#Q2) Take a person's age as input. If age is 18 or above, print "Eligible to vote", else print "Not eligible".

# %%
age = int(input("Enter your age: "))

if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible")
# Out:
# Enter your age:  15
# Not eligible

# %%
#Q3) Ask the user to enter a number. Print "Even" if it's divisible by 2, else print "Odd".

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Enter a number:  10
# Number is even

# %%
#Q4) Take two numbers as input. Print whichever number is greater. If both are equal, print "Equal".

# %%
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))

if num1 > num2:
    print("Number 1 is greater")
elif num1 < num2:
    print("Number 1 is greater")
else:
    print("Equal")
# Out:
# Enter a number:  50
# Enter a number:  50
# Equal

# %%
#Q5) Ask the user to enter a temperature in Celsius. If it's above 30, print "Hot day". If between 15 and 30, print "Pleasant". Below 15, print "Cold day".

# %%
temp = int(input("Enter temperature: "))

if temp > 30:
    print("Hot day")
elif 15 < temp < 30:
    print("Pleasant") 
elif temp <= 15:
    print("Cold day")
# Out:
# Enter temperature:  15
# Cold day

# %%
#Q6) Take a number as input. Check if it is divisible by 5. Print "Divisible by 5" or "Not divisible by 5".

# %%
num = int(input("Enter a number: "))

if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Enter a number:  13
# Not divisible by 5

# %%
#Q7) Ask the user to enter a character. Print "Vowel" if it is a, e, i, o, or u, else print "Consonant".

# %%
val = input("Enter a character: ")

if val in ("aeiou"):
    print("Vower")
else:
    print("Consonant")
# Out:
# Enter a character:  q
# Consonant

# %%
#Q8) Take a number as input. If it is between 1 and 100 (inclusive), print "In range", else print "Out of range".

# %%
num = int(input("Enter a number: "))

if num in range(1,101):
    print("In range")
else:
    print("Out of range")
# Out:
# Enter a number:  101
# Out of range

# %%
#Q9) Ask the user their marks out of 100. Print "Pass" if marks are 40 or above, else print "Fail".

# %%
mark = float(input("Enter your mark: "))

if mark >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your mark:  39
# Fail

# %%
#Q10) Take a number as input. Check if it's single digit, double digit or triple digit.

# %%
num = float(input("Enter a number: "))

if num in range(0,10):
    print("Single digit")
elif num in range(10,100):
    print("Double digit") 
elif num in range(100,1000):  
    print("Triple digit")
# Out:
# Enter a number:  10
# Double digit

# %%
#Q11) Take marks as input and print the grade: A (90–100), B (75–89), C (60–74), D (40–59), F (below 40).

# %%
num = float(input("Enter your mark: "))

if num >= 90 and num <= 100:
    print("A Grade")
elif num >= 75 and num <= 89:
    print("B Grade") 
elif num >= 60 and num <= 74:
    print("C Grade") 
elif num >= 40 and num <= 59:
    print("D Grade")  
else:
    print("Fail")
# Out:
# Enter your mark:  10
# Fail

# %%
#Q12) Take three numbers as input. Print the largest among the three without using max().

# %%
num1 = float(input("Enter your mark: "))
num2 = float(input("Enter your mark: "))
num3 = float(input("Enter your mark: "))

if num1 > num2 and num1 > num3:
    print("num1 is largest")
elif num2 > num1 and num2 > num3:
    print("num2 is largest")    
else:
    print("num3 is largest")
# Out:
# Enter your mark:  25
# Enter your mark:  13
# Enter your mark:  50
# num3 is largest

# %%
#Q13) Ask the user to enter a year. Print "Leap year" if it satisfies the leap year conditions, else print "Not a leap year".

# %%
year = int(input("Enter a year: "))

if year % 400 == 0:
    print("Leap year")
elif year % 100 == 0:
    print("Not a leap year")
elif year % 4 == 0:
    print("Leap year")
else:
    print("Not a leap year")
# Out:
# Enter a year:  2022
# Not a leap year

# %%
#Q14) Take a number as input. Print "Fizz" if divisible by 3, "Buzz" if divisible by 5, "FizzBuzz" if divisible by both, else print the number itself.

# %%
num = float(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print("FizzBuzz")
elif num % 3 == 0:
    print("Fizz")
elif num % 5 == 0:
    print("Buzz")
else:
    print(num)
# Out:
# Enter a number:  15
# FizzBuzz

# %%
#Q15) Ask the user to enter their BMI. Print the category: Below 18.5 → Underweight, 18.5 to 24.9 → Normal, 25 to 29.9 → Overweight, 30 and above → Obese

# %%
n = float(input("Enter your BMI : "))

if n < 18.5:
    print("Underweight")
elif n >= 18.5 and n <= 24.5:
    print("Normal")
elif n >= 25 and n<= 29.9:
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter your BMI :  22.5
# Normal
